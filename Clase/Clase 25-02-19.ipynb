# %%
#Funciones
#Nos permiten reducir código, ya que se pueden reutilizar dentro de algún programa
# def, define a la función y el proceso que se este realizando dentro de esta

# def nombredelafuncion(x,y,z=0): #los argumentos pueden ser opcionales
#	"Una descripción de que es lo que realiza la función"
#	Aqui va la programación para resolver los datos
#	return resultados
#return es opcional, no todas las funciones deben de regresar el resultado a consola, talvez sólo
#tengan que realizar cierto procedimiento dentro de la estructura de la programación.


def holamundo():
    """Función que imprime la frase Hola Mundo"""
    print("hola mundo")

holamundo()

def suma(a,b=10):
    c=0
    c=a+b
    return c

print(suma(5,19))


def promedio(datos):
    """Regresa el promedio de una lista de datos"""
    prom=0
    for i in datos:
        prom=prom+i
    return prom/len(datos)

print(promedio([1,3,4]))


def triangle(x,y):
    if (x or y) <= 0:
        return "No se puede"
    else:
        a=(x*y)/2
        return a

print(triangle(-3,-4))

#ejericio 1: Crear una función que me regrese cuántos numeros 1 hay dentro de una lista que introducimos manualmente

def unos(x):
    cont=0
    for i in x:
        if i is 1:
            cont=cont+1
    return cont
 
print(unos([10,3,4]))


#Ejercicio 2: Crear una funcion que genere una lista de tamaño n (la lista tiene que tener un tamaño mínimo de 2)
#con valores aleatorios entre x y y, donde y es el valor más grande y x el más pequeño

def randlist(n,x,y):
    import random
    l=[] 
    if n < 2:
        print("Tamaño mínimo de la lista debe de ser 2")
    elif x>y:
        print("x debe ser mayor a y")
    else:
        for i in range(0,n):
            l.append(random.randint(x,y))
    return l

x=randlist(100,1,7)
print(x)

#Crear una función que cuente cuantos numeros pares e impares existen dentro de la lista creada en el ejercicio anterior 
#y lo regrese en una tupla

print(unos(x))

#Crear una función que regrese una matriz cuadrada con números flotantes entre (x,y)
# Out:
# hola mundo
# 24
# 2.6666666666666665
# No se puede
# 0
# [6, 4, 4, 5, 1, 1, 3, 7, 3, 2, 1, 7, 3, 1, 4, 7, 2, 4, 5, 6, 5, 2, 4, 6, 2, 1, 7, 7, 5, 1, 3, 1, 1, 7, 7, 2, 1, 7, 3, 4, 3, 1, 6, 5, 6, 4, 7, 2, 2, 3, 6, 5, 1, 7, 4, 7, 6, 2, 3, 1, 3, 2, 7, 5, 4, 7, 7, 6, 3, 4, 1, 5, 4, 6, 2, 6, 6, 3, 2, 3, 3, 2, 3, 4, 2, 6, 4, 7, 2, 3, 7, 2, 3, 4, 1, 7, 5, 1, 4, 3]
# 15
